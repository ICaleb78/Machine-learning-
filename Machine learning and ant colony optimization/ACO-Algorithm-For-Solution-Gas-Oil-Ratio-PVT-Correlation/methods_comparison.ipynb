# %% [markdown]
# # Comparison of Gas Solubility Models
# We will compare the experimental data with the gas solubility values (scf/stb) derived from different models in this notebook. The models that are being compared are:
# - Glaso
# - Standing
# - This Study (current model)
#
# > Standard Cubic Feet per Stock Tank Barrel is referred to as SCF/STB. The amount of gas that can dissolve in oil under typical circumstances is measured using this unit of measurement in the oil and gas sector. The terms are broken down as follows:

# %% [markdown]
# - Standard Cubic Foot, or SCF for short, is the volume of gas at standard circumstances of pressure and temperature, which are usually expressed as 14.7 psi (1 atmosphere) and 60°F (15.6°C).
#
# - A 42-gallon barrel of oil tested under normal conditions is referred to as an STB (stock tank barrel). This is usually done after the oil has been stabilized by eliminating any dissolved gasses and separating any water content.
#
# - Consequently, SCF/STB measures the volume of gas that, under typical circumstances, can dissolve in a single barrel of oil from a stock tank.

# %% [markdown]
# ### Comparative Analysis Note
#
# **Objective:**
# To compare the performance of the current study's model with existing gas solubility correlations, namely Glaso, Standing, and Petrosky and Farshad, in predicting the gas solubility (scf/stb) at various pressure levels.

# %% [markdown]
# # Comparison of Gas Solubility Models
#
# ![Input Data](../Image/input.PNG)
#
# ## Comparison Table
#
# The table below shows the gas solubility values (scf/stb) obtained from various models compared with the experimental data:
#
# ![Comparison Table](../Image/Captured55.PNG)
#
# ## Visualization of Results
#
# The results are plotted in the figure below to show the disparity in values of the correlations from the experimental data:
#
# ![Result Plot](../Image/Distributions.PNG)

# %% [markdown]
# # Comparing with Ant Colony Optimization Algorithm - Glaso

# %% [markdown]
# **Data:**
# The table provides gas solubility values from the following sources:
#
#
# | Pressure (psig) | Experimental | Glaso | Ant Colony Optimization |
# |-----------------|--------------|-------|-------------------------|
# | 2405            | 737          | 665   | 708.0571753             |
# | 2200            | 684          | 500   | 665.3058239             |
# | 1950            | 620          | 425   | 611.8100762             |
# | 1700            | 555          | 388   | 556.5658767             |
# | 1450            | 492          | 319   | 499.2094992             |
# | 1200            | 429          | 285   | 439.2216859             |
# | 950             | 365          | 205   | 375.8116207             |
# | 700             | 301          | 165   | 307.6555236             |
# | 450             | 235          | 100   | 232.1705220             |
# | 200             | 155          | 55    | 142.5189201             |

# %% [markdown]
# ### Visualization comparing the different models with the experimental data

# %%
import matplotlib.pyplot as plt

# Data
pressure = [2405, 2200, 1950, 1700, 1450, 1200, 950, 700, 450, 200]
experimental = [737, 684, 620, 555, 492, 429, 365, 301, 235, 155]
glaso = [665, 500, 425, 388, 319, 285, 205, 165, 100, 55]
ant_co = [708.05717537,665.30582395,611.81007622,556.56587679,499.20949921,439.22168591,375.81162071,307.65552361,232.17052203,142.51892014]

# Plot
plt.figure(figsize=(6, 6))
plt.plot(pressure, experimental, 'o-', color='blue', label='Experimental')
plt.plot(pressure, glaso, 's--', color='orange', label='Glaso')
plt.plot(pressure, ant_co, 'x-', color='purple', label='Ant Colony')

# Title and labels
plt.title('Comparison of Gas Solubility Models')
plt.xlabel('Pressure (psig)')
plt.ylabel('Gas Solubility (scf/stb)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Statistical Comparison of Gas Solubility Models
#
# This section provides a statistical comparison of the gas solubility (scf/stb) results from our model with existing models like Glaso & Standing.

# %% [markdown]
# ### Insights on the Comparison of Models
#
# The table below compares the performance of the **Ant Colony Optimization (ACO)** algorithm with other models (Glaso, Standing, and Petrosky and Farshad) based on three key metrics:
#
# | Metric                          | ACO Algo   | Glaso  | Standing  |
# |---------------------------------|------------|--------|-----------|
# | Correlation Coefficient         | 0.998      | 0.9167 | 0.8097    |
# | Average Percent Relative Error  | 2.64%      | 30.22% | 40.11%    |
# | Sum of Squared Residuals        | 1738.12    | 566488 | 522387    |
#
# #### 1. **Correlation Coefficient:**
# - The **ACO Algorithm** demonstrates the highest correlation coefficient (0.998), indicating that it has a strong linear relationship with the experimental data. This suggests that the model's predictions are very close to the actual values.
# - In comparison, the **Glaso** model (0.9167), **Standing** (0.8097), and **Petrosky and Farshad** (0.8089) models have weaker correlations, which means their predictions are less consistent with the actual values.
#
# #### 2. **Average Percent Relative Error:**
# - The **ACO Algorithm** has the lowest average percent relative error (2.64%), suggesting that it provides the most accurate predictions compared to the other models.
# - The **Glaso** model has a much higher error rate (30.22%), indicating that its predictions are significantly less accurate.
# - **Standing** and **Petrosky and Farshad** models also show high error rates (40.11% and 29.3%, respectively), implying that these models are less reliable in predicting the actual gas-to-oil ratios.
#
# #### 3. **Sum of Squared Residuals:**
# - The **ACO Algorithm** has the smallest sum of squared residuals (1738.12), indicating that the difference between the predicted and actual values is minimal. A lower sum of squared residuals is a sign of a better-fitting model.
# - The **Glaso** model has a significantly higher sum of squared residuals (566488), suggesting that the model's predictions deviate considerably from the actual data.
# - Both the **Standing** (522387) and **Petrosky and Farshad** (373945) models also show large residuals, reflecting their relatively poor fit compared to ACO.
#
# ### Conclusion:
# - The **ACO Algorithm** outperforms the other models in terms of correlation, accuracy, and fitting the data, making it the best choice among the models compared.
# - The high correlation and low error rates suggest that **ACO** is an effective optimization method for estimating the gas-to-oil ratio (Rs) based on the provided conditions.n

# %% [markdown]
# __

# %% [markdown]
# # Comparing with Ant Colony Optimization Algorithm - Standing

# %%
import matplotlib.pyplot as plt

# Data
pressure = [2405, 2200, 1950, 1700, 1450, 1200, 950, 700, 450, 200]
experimental = [737, 684, 620, 555, 492, 429, 365, 301, 235, 155]
standing = [703, 735, 658, 575, 493, 309, 242, 185, 100, 45]
ant_co = [723.37811561,677.90992981,620.87204676,561.81402026,500.34836693,435.93047456,367.74611347,294.46282274,213.55523244,118.60109251]

# Plot
plt.figure(figsize=(6, 6))
plt.plot(pressure, experimental, 'o-', color='blue', label='Experimental')
plt.plot(pressure, standing, 's--', color='orange', label='Standing')
plt.plot(pressure, ant_co, 'x-', color='purple', label='Ant Colony')

# Title and labels
plt.title('Comparison of Gas Solubility Models')
plt.xlabel('Pressure (psig)')
plt.ylabel('Gas Solubility (scf/stb)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# | Metric                          | ACO Algo   | Glaso  | Standing  |
# |---------------------------------|------------|--------|-----------|
# | Correlation Coefficient         | 0.998      | 0.9167 | 0.8097    |
# | Average Percent Relative Error  | 4.30%      | 30.22% | 40.11%    |

# %% [markdown]
# > In conclusion, our study not only contributes a novel empirical correlation for GOR estimation but also showcases the effectiveness of the ACO algorithm in optimizing predictive models for oil and gas reservoir engineering. This work sets a foundation for further advancements in computational optimization techniques tailored to industry-specific challenges.

# %% [markdown]
# ## Insights on the Comparison of ACO Algorithm, Glaso, and Standing Methods
#
# The following table provides a comparison of three methods (ACO Algorithm, Glaso, and Standing) based on two key metrics: **Correlation Coefficient** and **Average Percent Relative Error**. The comparison allows us to analyze the performance and accuracy of the methods.
#
# | Metric                          | ACO Algo   | Glaso  | Standing  |
# |---------------------------------|------------|--------|-----------|
# | Correlation Coefficient         | 0.998      | 0.9167 | 0.8097    |
# | Average Percent Relative Error  | 4.30%      | 30.22% | 40.11%    |
#
# ### 1. **Correlation Coefficient**
# - **ACO Algorithm (0.998)**: The ACO algorithm demonstrates a very high correlation coefficient, indicating a strong relationship between the predicted and actual values. A correlation of 0.998 is very close to 1, suggesting that the model's predictions are highly reliable.
# - **Glaso (0.9167)**: Glaso shows a good correlation coefficient, though it is slightly lower than ACO. This indicates that while Glaso provides reasonably accurate predictions, there is more deviation from actual values compared to ACO.
# - **Standing (0.8097)**: Standing has the lowest correlation coefficient, suggesting a weaker relationship between predicted and actual values. This implies that the Standing method may not be as accurate in predicting outcomes as ACO or Glaso.
#
# ### 2. **Average Percent Relative Error**
# - **ACO Algorithm (4.30%)**: The ACO algorithm shows the lowest error percentage, meaning it is the most accurate among the three methods. The 4.30% error is relatively small, which signifies that the model's predictions are very close to the actual values.
# - **Glaso (30.22%)**: Glaso has a significantly higher error percentage, indicating that its predictions are less accurate compared to ACO. The larger error (30.22%) suggests that this model has a higher degree of deviation from actual values.
# - **Standing (40.11%)**: Standing has the highest error percentage, making it the least accurate method of the three. The high error rate of 40.11% indicates substantial deviation from the actual values, suggesting that improvements are needed to enhance its predictive accuracy.
#
# ### Conclusion
# - **ACO Algorithm** outperforms both **Glaso** and **Standing** in terms of both correlation coefficient and average percent relative error. Its high correlation and low error suggest that it is a more reliable method for the given problem.
# - **Glaso** performs reasonably well but falls short of ACO, especially in terms of error rate.
# - **Standing** has the lowest performance among the three, with a significantly higher error and a lower correlation coefficient.
